# %% [markdown]
# <a href="https://colab.research.google.com/github/SergioMosquera/traffic_crashes_data/blob/main/Traffic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
chicago_data = 'https://raw.githubusercontent.com/terranigmark/curso-analisis-exploratorio-datos-platzi/main/Traffic_Crashes1.csv'
token_map_plot = 'pk.eyJ1IjoiemJveDAiLCJhIjoiY2txNWR3ZHFxMWhnODJ3cWI4bTBraWYxMyJ9.L3MtPTQgxFJYqMiuU685_w'

# %%
import pandas as pd
df_chicago = pd.read_csv(chicago_data)

# %%
df_chicago.head()
# Out:
#    Unnamed: 0  ...   date_real
# 0      290702  ...  2017-02-14
# 1      405524  ...  2019-08-13
# 2      261834  ...  2019-05-22
# 3       38519  ...  2017-06-14
# 4      420197  ...  2018-05-03
#
# [5 rows x 51 columns]

# %% [markdown]
# CRASH_DATE sera transformada a datatime, y se agregara al df con el nombre de CRASH_DATE_time, esta es una transformacion comun en Python, en R define los tipos de datos automaticamente.

# %%
df_chicago['CRASH_DATE_time'] = df_chicago['CRASH_DATE'].apply(lambda x: pd.to_datetime(x, errors='coerce',utc=True))
df_chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27961 entries, 0 to 27960
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     27961 non-null  int64
#  1   CRASH_RECORD_ID                27961 non-null  object
#  2   RD_NO                          27713 non-null  object
#  3   CRASH_DATE_EST_I               2117 non-null   object
#  4   CRASH_DATE                     27961 non-null  object
#  5   POSTED_SPEED_LIMIT             27961 non-null  int64
#  6   TRAFFIC_CONTROL_DEVICE         27961 non-null  object
#  7   DEVICE_CONDITION               27961 non-null  object
#  8   WEATHER_CONDITION              27961 non-null  object
#  9   LIGHTING_CONDITION             27961 non-null  object
#  10  FIRST_CRASH_TYPE               27961 non-null  object
#  11  TRAFFICWAY_TYPE                27961 non-null  object
# ...

# %%
df_chicago['NUM_UNITS'] = df_chicago['NUM_UNITS'].astype('int32')
